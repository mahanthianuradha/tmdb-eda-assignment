# %% [markdown]
# <a href="https://colab.research.google.com/github/mahanthianuradha/tmdb-eda-assignment/blob/main/tmdb_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

url = "https://api.themoviedb.org/3/authentication"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3OThmNTk3ZTliNGIxMDZmYzY1NWUzYzhkNTE5MTAwMiIsIm5iZiI6MTc3NDcxNDk5NC45MzI5OTk4LCJzdWIiOiI2OWM4MDA3Mjc5MWE5N2JmODg5ZGViNGUiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.seoaNETicmhFzjCOYX4Rp69RK8E1mH5nlMy7XUZGVAQ"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"success":true}

# %%
import requests

from google.colab import userdata

api_key = userdata.get('tmdb')


url = "https://api.themoviedb.org/3/authentication"
params = {
    "api_key": api_key
}
response = requests.get(url,params = params)

print(response.json())
# Out:
# {'success': True}

# %%
url = "https://api.themoviedb.org/3/discover/movie"
params = {
    "api_key":api_key
}


response = requests.get(url,params = params)
responseJson = response.json()
print(responseJson['total_results'])
# Out:
# 1117551

# %%
import requests
import pandas as pd
import sqlite3
import json

url = "https://api.themoviedb.org/3/discover/movie"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3OThmNTk3ZTliNGIxMDZmYzY1NWUzYzhkNTE5MTAwMiIsIm5iZiI6MTc3NDcxNDk5NC45MzI5OTk4LCJzdWIiOiI2OWM4MDA3Mjc5MWE5N2JmODg5ZGViNGUiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.seoaNETicmhFzjCOYX4Rp69RK8E1mH5nlMy7XUZGVAQ"
}

response = requests.get(url, headers=headers)


data = response.json()
movies_df = pd.DataFrame(data['results'])
top_25movies = movies_df.head(25)


top_25movies['genre_ids'] = top_25movies['genre_ids'].apply(json.dumps)

#print(top_25movies)

conn = sqlite3.connect("tmdb_database.db")
movies_sql = top_25movies.to_sql("movies" , conn ,if_exists='replace', index = False)
#print(movies_sql)



query = "SELECT * FROM MOVIES  "

df_movies = pd.read_sql(query,conn)
df_movies['genre_ids'] = df_movies['genre_ids'].apply(json.loads)
df_movies.head()
df_movies.describe()
df_movies.columns
#movies_genre = df_movies.groupby('genre_ids')['id'].count()
#print(movies_genre)
print(df_movies.isna().sum())
# Out:
# adult                0
# backdrop_path        0
# genre_ids            0
# id                   0
# original_language    0
# original_title       0
# overview             0
# popularity           0
# poster_path          0
# release_date         0
# title                0
# video                0
# vote_average         0
# vote_count           0
# dtype: int64
